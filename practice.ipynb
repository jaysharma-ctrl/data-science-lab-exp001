# %% [markdown]
# <a href="https://colab.research.google.com/github/jaysharma-ctrl/data-science-lab-exp001/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Name": ["Jay", "Rahul", "Aman", "Riya"],
    "Age": [20, 21, 19, 20],
    "City": ["Mathura", "Delhi", "Agra", "Jaipur"]
}

student_df = pd.DataFrame(data)

# %%
print(student_df)
# Out:
#     Name  Age     City
# 0    Jay   20  Mathura
# 1  Rahul   21    Delhi
# 2   Aman   19     Agra
# 3   Riya   20   Jaipur

# %%
print(student_df.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
print(student_df["Name"])
# Out:
# 0      Jay
# 1    Rahul
# 2     Aman
# 3     Riya
# Name: Name, dtype: object

# %%
print(student_df["City"])
# Out:
# 0    Mathura
# 1      Delhi
# 2       Agra
# 3     Jaipur
# Name: City, dtype: object

# %%
new_df = student_df[["Name", "City"]]

print(new_df)
# Out:
#     Name     City
# 0    Jay  Mathura
# 1  Rahul    Delhi
# 2   Aman     Agra
# 3   Riya   Jaipur

# %%
book_data = {
    "Book": ["Python", "Java", "C++", "SQL"],
    "Author": ["A", "B", "C", "D"],
    "Price": [300, 400, 350, 250]
}

book_df = pd.DataFrame(book_data)

print(book_df)
# Out:
#      Book Author  Price
# 0  Python      A    300
# 1    Java      B    400
# 2     C++      C    350
# 3     SQL      D    250

# %%
book_df["Publisher"] = "ABC Publishers"

print(book_df)
# Out:
#      Book Author  Price       Publisher
# 0  Python      A    300  ABC Publishers
# 1    Java      B    400  ABC Publishers
# 2     C++      C    350  ABC Publishers
# 3     SQL      D    250  ABC Publishers

# %%
df = pd.DataFrame({
    "Name": ["A", "B", "C", "D", "E"]
})

df["SerialNo"] = np.arange(5)

print(df)
# Out:
#   Name  SerialNo
# 0    A         0
# 1    B         1
# 2    C         2
# 3    D         3
# 4    E         4

# %%
df = df.drop("SerialNo", axis=1)

print(df)
# Out:
#   Name
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
movie_data = {
    "Movie": ["Dangal", "3 Idiots", "PK", "Pathaan"],
    "Year": [2016, 2009, 2014, 2023],
    "Rating": [8.3, 8.4, 8.1, 5.9]
}

movie_df = pd.DataFrame(movie_data)

print(movie_df)
# Out:
#       Movie  Year  Rating
# 0    Dangal  2016     8.3
# 1  3 Idiots  2009     8.4
# 2        PK  2014     8.1
# 3   Pathaan  2023     5.9

# %%
new_movie_df = pd.DataFrame({
    "Movie": movie_df["Movie"],
    "Rating": movie_df["Rating"],
    "Director": ["Nitesh Tiwari", "Rajkumar Hirani", "Rajkumar Hirani", "Siddharth Anand"]
})

print(new_movie_df)
# Out:
#       Movie  Rating         Director
# 0    Dangal     8.3    Nitesh Tiwari
# 1  3 Idiots     8.4  Rajkumar Hirani
# 2        PK     8.1  Rajkumar Hirani
# 3   Pathaan     5.9  Siddharth Anand

# %%
city_series =pd.Series(["Mathura", "Delhi"])
index=[0,3]
print(city_series)
# Out:
# 0    Mathura
# 1      Delhi
# dtype: object

# %%
df=pd.DataFrame({"Name":["jay","Rahul","Aman","dhruv"]})
df["Branch"]=city_series
print(df)
# Out:
#     Name   Branch
# 0    jay  Mathura
# 1  Rahul    Delhi
# 2   Aman      NaN
# 3  dhruv      NaN

# %%
employee_df = pd.DataFrame({
    "Employee": ["Aman", "Rahul", "Priya", "Neha", "Rohan"],
    "Department": ["IT", "HR", "Finance", "IT", "Sales"],
    "Experience": [2, 4, 3, 5, 1]
})

print(employee_df)

new_df = employee_df[["Employee", "Experience"]]
print(new_df)
# Out:
#   Employee Department  Experience
# 0     Aman         IT           2
# 1    Rahul         HR           4
# 2    Priya    Finance           3
# 3     Neha         IT           5
# 4    Rohan      Sales           1
#   Employee  Experience
# 0     Aman           2
# 1    Rahul           4
# 2    Priya           3
# 3     Neha           5
# 4    Rohan           1

# %%
print(employee_df["Department"])

print(employee_df.columns)
# Out:
# 0         IT
# 1         HR
# 2    Finance
# 3         IT
# 4      Sales
# Name: Department, dtype: object
# Index(['Employee', 'Department', 'Experience'], dtype='object')

# %%
employee_df["Office"] = "Head Office"

print(employee_df)
# Out:
#   Employee Department  Experience       Office
# 0     Aman         IT           2  Head Office
# 1    Rahul         HR           4  Head Office
# 2    Priya    Finance           3  Head Office
# 3     Neha         IT           5  Head Office
# 4    Rohan      Sales           1  Head Office

# %%
employee_df["Office"] = np.arange(5)

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0     Aman         IT           2       0
# 1    Rahul         HR           4       1
# 2    Priya    Finance           3       2
# 3     Neha         IT           5       3
# 4    Rohan      Sales           1       4

# %%
office_names = pd.Series(
    ["Delhi", "Mumbai", "Pune"],
    index=[0, 2, 4]
)

employee_df["Office"] = office_names

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0     Aman         IT           2   Delhi
# 1    Rahul         HR           4     NaN
# 2    Priya    Finance           3  Mumbai
# 3     Neha         IT           5     NaN
# 4    Rohan      Sales           1    Pune

# %%
del employee_df["Office"]

print(employee_df)
# Out:
#   Employee Department  Experience
# 0     Aman         IT           2
# 1    Rahul         HR           4
# 2    Priya    Finance           3
# 3     Neha         IT           5
# 4    Rohan      Sales           1

# %%
product_df = pd.DataFrame({
    "Product": ["Laptop", "Phone", "Tablet"],
    "Category": ["Electronics", "Electronics", "Electronics"],
    "Price": [50000, 30000, 20000]
})

new_product_df = product_df[["Price", "Product", "Category"]]

print(new_product_df)
# Out:
#    Price Product     Category
# 0  50000  Laptop  Electronics
# 1  30000   Phone  Electronics
# 2  20000  Tablet  Electronics

# %%
data = {
    "Name": ["Aman", "Rahul", "Priya"],
    "Age": [20, 21, 19],
    "City": ["Delhi", "Mumbai", "Pune"]
}

df = pd.DataFrame(data, columns=["Name", "Age", "City", "Salary"])

print(df)
# Out:
#     Name  Age    City Salary
# 0   Aman   20   Delhi    NaN
# 1  Rahul   21  Mumbai    NaN
# 2  Priya   19    Pune    NaN

# %%
df = pd.DataFrame({
    "Name": ["Aman", "Rahul", "Priya"],
    "Total Marks": [85, 90, 78]
})

print(df["Total Marks"])
# Out:
# 0    85
# 1    90
# 2    78
# Name: Total Marks, dtype: int64

# %%
data = {
    'Product': ['Laptop', 'Mouse', 'Keyboard', 'Monitor'],
    'Category': ['Electronics', 'Accessories', 'Accessories', 'Electronics'],
    'Price': [55000, 500, 1200, 8500]
}

product_df = pd.DataFrame(data)
print("Original DataFrame:")
print(product_df)
# Out:
# Original DataFrame:
#     Product     Category  Price
# 0    Laptop  Electronics  55000
# 1     Mouse  Accessories    500
# 2  Keyboard  Accessories   1200
# 3   Monitor  Electronics   8500

# %%
course_df = pd.DataFrame({
    'Student': ['Amit', 'Priya', 'Rahul', 'Sneha', 'Vikram'],
    'Course': ['Python', 'Java', 'Python', 'C++', 'Java'],
    'Score': [85, 90, 78, 88, 92]})
print(course_df.columns)
print(course_df['Student'])
student_score_df = course_df[['Student', 'Score']]
print(student_score_df)
course_df['Batch'] = '2026-A'
print(course_df)
# Out:
# Index(['Student', 'Course', 'Score'], dtype='object')
# 0      Amit
# 1     Priya
# 2     Rahul
# 3     Sneha
# 4    Vikram
# Name: Student, dtype: object
#   Student  Score
# 0    Amit     85
# 1   Priya     90
# 2   Rahul     78
# 3   Sneha     88
# 4  Vikram     92
#   Student  Course  Score   Batch
# 0    Amit  Python     85  2026-A
# 1   Priya    Java     90  2026-A
# 2   Rahul  Python     78  2026-A
# 3   Sneha     C++     88  2026-A
# 4  Vikram    Java     92  2026-A

# %%
travel_df = pd.DataFrame({
    'Destination': ['Goa', 'Manali', 'Jaipur', 'Kerala', 'Shimla'],
    'Days': [4, 5, 3, 6, 4]
})
travel_df['Code'] = np.arange(5)
print("After adding Code with np.arange(5):")
print(travel_df)
# Out:
# After adding Code with np.arange(5):
#   Destination  Days  Code
# 0         Goa     4     0
# 1      Manali     5     1
# 2      Jaipur     3     2
# 3      Kerala     6     3
# 4      Shimla     4     4

# %%
data = {
    'Student': ['Anita', 'Rohan', 'Kavya'],
    'Class': [8, 9, 8],
    'Section': ['A', 'B', 'A']
}
school_df = pd.DataFrame(data)
print("Original school_df:")
print(school_df)
extended_df = pd.DataFrame(school_df, columns=['Student', 'Class', 'Section', 'House'])
print("\nExtended DataFrame with House (not yet filled):")
print(extended_df)
# Out:
# Original school_df:
#   Student  Class Section
# 0   Anita      8       A
# 1   Rohan      9       B
# 2   Kavya      8       A
#
# Extended DataFrame with House (not yet filled):
#   Student  Class Section  House
# 0   Anita      8       A    NaN
# 1   Rohan      9       B    NaN
# 2   Kavya      8       A    NaN

# %%
inventory_df = pd.DataFrame({
    'Item': ['Pen', 'Notebook', 'Eraser', 'Sharpener', 'Ruler'],
    'Quantity': [100, 50, 200, 150, 80],
    'Price': [10, 40, 5, 8, 15]
})
discount_series = pd.Series([2, 5], index=[0, 3])
inventory_df['Discount'] = discount_series
print("After adding Discount column (partial values):")
print(inventory_df)
# Out:
# After adding Discount column (partial values):
#         Item  Quantity  Price  Discount
# 0        Pen       100     10       2.0
# 1   Notebook        50     40       NaN
# 2     Eraser       200      5       NaN
# 3  Sharpener       150      8       5.0
# 4      Ruler        80     15       NaN
